# %%
import pandas as pd

#读取excel数据
#data=pd.read_excel("C:\\Users\\Admin\\Desktop\\xxl-job.xlsx")
#路径加前缀r,不需要进行转义
data=pd.read_excel(r"C:\Users\Admin\Desktop\xxl-job.xlsx")


print(data.describe())
data.head(20)
# Out:
#        任务参数
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
#                                  任务描述         负责人      调度类型            调度配置  \
# 0                         每年更新花名册人员年纪   liuweimin      CRON     0 0 0 1 1 ?
# 1                     看板刷新-智能安全帽-电子围栏   dengliyao  FIX_RATE              40
# 2        看板刷新-智能安全帽-人员是否在线信息列表及人员帽子位置   dengliyao  FIX_RATE              40
# 3                   看板刷新-人员信息-实名制人员统计   dengliyao      CRON     0 0 0 * * ?
# 4                  看板刷新-人员信息-在册人员工种统计   dengliyao      CRON     0 0 0 * * ?
# 5                  看板刷新-人员信息-项目现场统计信息   dengliyao  FIX_RATE              40
# 6                   看板刷新-人员信息-近7天考勤信息   dengliyao      CRON     0 0 0 * * ?
# 7                看板刷新-人员信息-人员所属单位在场人数   dengliyao      CRON     0 0 0 * * ?
# 8                      看板刷新-人员信息-最新考勤   dengliyao  FIX_RATE              40
# 9                  劳务实名制推送iot异常补偿定时任务  maoyanfeng      CRON  0 0/30 * * * ?
# ...
